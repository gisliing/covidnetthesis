# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 9840407255550469088,
#  name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 5129561610408790808
#  physical_device_desc: "device: XLA_CPU device",
#  name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 3017590219543503344
#  physical_device_desc: "device: XLA_GPU device",
#  name: "/device:XLA_GPU:1"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 7597605794613578491
#  physical_device_desc: "device: XLA_GPU device",
#  name: "/device:XLA_GPU:2"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 9083145894144240889
#  physical_device_desc: "device: XLA_GPU device",
#  name: "/device:XLA_GPU:3"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 8111425487632433574
#  physical_device_desc: "device: XLA_GPU device",
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15660990464
#  locality {
#    bus_id: 1
#    links {
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 8520873204270456009
#  physical_device_desc: "device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 0000:3b:00.0, compute capability: 7.0",
#  name: "/device:GPU:1"
#  device_type: "GPU"
#  memory_limit: 15660990464
#  locality {
#    bus_id: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 17188178069493988972
#  physical_device_desc: "device: 1, name: Tesla V100-PCIE-16GB, pci bus id: 0000:61:00.0, compute capability: 7.0",
#  name: "/device:GPU:2"
#  device_type: "GPU"
#  memory_limit: 15660990464
#  locality {
#    bus_id: 2
#    numa_node: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 2085306205986491987
#  physical_device_desc: "device: 2, name: Tesla V100-PCIE-16GB, pci bus id: 0000:da:00.0, compute capability: 7.0",
#  name: "/device:GPU:3"
#  device_type: "GPU"
#  memory_limit: 15660990464
#  locality {
#    bus_id: 2
#    numa_node: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 11899727892821022021
#  physical_device_desc: "device: 3, name: Tesla V100-PCIE-16GB, pci bus id: 0000:db:00.0, compute capability: 7.0"]

# %%
import sys
sys.path.insert(1, '/p/project/joaiml/CovidNet')
