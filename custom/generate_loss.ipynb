# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
r0 = [0.7422239, 0.7978767, 0.63639516, 0.30806667, 0.25307143, 0.76128125, 0.5984572, 0.11581412, 0.6465005, 0.3906378, 0.62880254, 0.08203966, 0.040025197, 0.015168682, 0.020530852, 0.0094707385, 0.007659558, 0.011689952, 0.007459917, 0.23082274, 0.23854005, 0.035437208, 0.07681135, 0.007777731, 0.635325]
r1 = [0.65121555, 0.7423547, 0.5850889, 0.41888595, 0.4959467, 0.5686147, 0.28554064, 0.40171972, 0.17340356, 0.25602934, 0.23921224, 0.06436542, 0.05839249, 0.03795489, 0.00745261, 0.2728147, 0.022752102, 0.4877522, 0.159996, 0.026289493, 0.009999379, 0.089385495, 0.03627861, 0.009453975, 0.17089939]
r2 = [0.54095054, 0.48552305, 0.37802565, 0.17392248, 0.18753625, 0.58793294, 0.054344233, 0.039499998, 0.03163061, 0.017561506, 0.022420974, 0.2671859, 0.005944738, 0.17562886, 0.12869976, 0.18655714, 0.0018898303, 0.010074979, 0.0040441803, 0.021210162, 0.012307631, 0.0026723046, 0.0016284517, 0.027293146, 0.021591444]
r3 = [0.51847917, 0.4763632, 0.43316045, 0.3592638, 0.30796397, 0.22838324, 0.14666381, 0.10980432, 0.06615443, 0.05146905, 0.04053906, 0.039336063, 0.04458466, 0.03392081, 0.015146769, 0.008454243, 0.06441454, 0.008292023, 0.01286652, 0.01763065, 0.1302658, 0.0036174192, 0.0025911122, 0.0007693317, 0.0008566991]

# %%
plt.figure(figsize=(20,5))

plt.title('Fusion set (80% train) - bs = 32')

plt.plot(r0, color='r', label='lr = 5e-5')
plt.plot(r1, color='g', label='lr = 7e-5')
plt.plot(r2, color='b', label='lr = 1e-5')
plt.plot(r3, color='k', label='lr = 5e-6')
#plt.plot(r4, color='k', label='pneumonia weight 1.7')


plt.xlabel('Epochs')
plt.ylabel('Loss')

#plt.ylim(0, 500000000)

plt.legend()
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(3, figsize=(20,15))
#fig.suptitle('Vertically stacked subplots')

ax[0].plot(r0, color='r', label='lr = 5e-5')
ax[0].plot(r1, color='g', label='lr = 7e-5')
ax[0].plot(r2, color='b', label='lr = 1e-5')
ax[0].plot(r3, color='k', label='lr = 5e-6')
ax[0].legend()
ax[0].grid()
ax[0].set_title('Fusion set (80% train) - bs = 32')

plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.tight_layout()
plt.show()
