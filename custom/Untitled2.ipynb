# %%
import cv2
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('/p/project/joaiml/ingolfsson1/COVID_Net/labels/train_COVIDx8A_fix.txt', sep=' ', names=['path', 'condition'])

# %%
df.head()
# Out:
#                                                                                                  path  \
# cohenSARS-10.1148rg.242035193-g04mr34g0-Fig8a-d...  SARS-10.1148rg.242035193-g04mr34g0-Fig8a-day0....
# cohenSARS-10.1148rg.242035193-g04mr34g0-Fig8b-d...  SARS-10.1148rg.242035193-g04mr34g0-Fig8b-day5....
# cohenSARS-10.1148rg.242035193-g04mr34g0-Fig8c-d...  SARS-10.1148rg.242035193-g04mr34g0-Fig8c-day10...
# cohenSARS-10.1148rg.242035193-g04mr34g04a-Fig4a...  SARS-10.1148rg.242035193-g04mr34g04a-Fig4a-day...
# cohenSARS-10.1148rg.242035193-g04mr34g04b-Fig4b...  SARS-10.1148rg.242035193-g04mr34g04b-Fig4b-day...
#
#                                                     condition
# cohenSARS-10.1148rg.242035193-g04mr34g0-Fig8a-d...  pneumonia
# cohenSARS-10.1148rg.242035193-g04mr34g0-Fig8b-d...  pneumonia
# cohenSARS-10.1148rg.242035193-g04mr34g0-Fig8c-d...  pneumonia
# cohenSARS-10.1148rg.242035193-g04mr34g04a-Fig4a...  pneumonia
# ...

# %%
df[df['condition'] == 'pneumonia'].iloc[0]['path']
# Out:
# 'SARS-10.1148rg.242035193-g04mr34g0-Fig8a-day0.jpeg'

# %%
df[df['condition'] == 'COVID-19'].iloc[0]['path']
# Out:
# 'auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg'

# %%
df[df['path'] == 'auntminnie-b-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg']
# Out:
#                                                                                                  path  \
# cohenauntminnie-b-2020_01_28_23_51_6665_2020_01...  auntminnie-b-2020_01_28_23_51_6665_2020_01_28_...
#
#                                                    condition
# cohenauntminnie-b-2020_01_28_23_51_6665_2020_01...  COVID-19

# %%
img1 = cv2.imread('/p/project/joaiml/ingolfsson1/COVID_Net/data/train/{}'.format(df[df['condition'] == 'pneumonia'].iloc[0]['path']))
img2 = cv2.imread('/p/project/joaiml/ingolfsson1/COVID_Net/data/train/{}'.format(df[df['condition'] == 'COVID-19'].iloc[0]['path']))

# %%
fig, ax = plt.subplots(1,2)

ax[0] = plt.imshow(img1)
ax[1] = plt.imshow(img2)

plt.show()

# %%
fig = plt.figure()

ax1 = fig.add_subplot(1,2,1)
ax1.imshow(img1)
plt.axis('off')

ax2 = fig.add_subplot(1,2,2)
ax2.imshow(img2)

plt.axis('off')
plt.show()
